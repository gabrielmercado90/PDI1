# %% [markdown]
# <a href="https://colab.research.google.com/github/gabriel990420/PDI1/blob/master/Clase2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# importar librerias necesarias

import numpy as np
import matplotlib.pyplot as plt
import cv2
import os



path = "/content/drive/My Drive/PDI/"
os.chdir(path)
# !pwd
# graficar imagenes estaticas en el notebook
# %matplotlib inline
# Out:
# /content/drive/My Drive/PDI

# %%
def mostrar4(im1, im2, im3, im4, title1="original", title2="R", title3="G", title4="B"):
  plt.figure(figsize=(14,14))
  plt.subplot(221), plt.imshow(im1), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(222), plt.imshow(im2, cmap='gray'), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.subplot(223), plt.imshow(im3, cmap='gray'), plt.title(title3)
  plt.xticks([]), plt.yticks([])
  plt.subplot(224), plt.imshow(im4, cmap='gray'), plt.title(title4)
  plt.xticks([]), plt.yticks([])
  plt.show()
  


IMAGE_DIRECTORY = '/content/drive/My Drive/PDI/rubik/rub07.jpg'
img_BGR = cv2.imread(IMAGE_DIRECTORY, cv2.IMREAD_COLOR)

b = img_RGB[:,:,0]
g = img_RGB[:,:,1]
r = img_RGB[:,:,2]

mostrar4(img_BGR,b,g,r,"original")

# %%
img_BGR = cv2.imread(IMAGE_DIRECTORY, cv2.IMREAD_COLOR)
img_RGB = cv2.cvtColor(img_BGR,cv2.COLOR_BGR2RGB)
r,g,b = cv2.split(img_RGB)

mostrar4(img_RGB,r,g,b,"original")

# %%
count = 2
plt.figure(figsize=(12,4))
plt.subplot(2,2,1), plt.imshow(img_RGB/255.0), plt.title("original")
plt.axis("off")

for i, lab in enumerate(["R", "G", "B"]):
  crgb = np.zeros(img_RGB.shape)
  crgb[:,:,i] = img_RGB[:,:,i]
  plt.subplot(2,2,count), plt.imshow(crgb/255.0), plt.title(lab)
  plt.axis("off")
  count += 1
  
plt.show()
