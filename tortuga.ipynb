# %% [markdown]
# <a href="https://colab.research.google.com/github/gabriel990420/PDI1/blob/master/tortuga.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# hola soy ricardo la tortuga que gime y baila

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# importar librerias necesarias

import numpy as np
import matplotlib.pyplot as plt
import cv2

# graficar imagenes estaticas en el notebook
# %matplotlib inline

# %% [markdown]
# Asi se deberia hacer en python

# %%
##image = cv2.imread('/content/drive/My Drive/PDI/tortuga.jpg')
##cv2.imshow("Image", image)
##cv2.waitKey(0)

# %%
from google.colab.patches import cv2_imshow
img = cv2.imread('/content/drive/My Drive/PDI/tortuga.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=480x360 at 0x7F8F52FE0630>

# %%
img_BGR = cv2.imread('/content/drive/My Drive/PDI/tortuga.jpg', cv2.IMREAD_COLOR)

plt.figure(figsize=(8,8))
plt.imshow(img_BGR)
plt.show()

# %% [markdown]
# # direccionar con lenguaje bash de terminal

# %%
# !pwd
# !ls
# %cd /content/drive/My Drive/PDI/
# !pwd
from google.colab.patches import cv2_imshow
img = cv2.imread("tortuga.jpg", cv2.IMREAD_UNCHANGED)
#img = cv2.resize(img, (int(500),int(500)))
cv2_imshow(img)
print(img.shape)
# Out:
# /content
# drive  sample_data
# /content/drive/My Drive/PDI
# /content/drive/My Drive/PDI
# <PIL.Image.Image image mode=RGB size=480x360 at 0x7F8F50ED62E8>
# (360, 480, 3)

# %% [markdown]
# # direccionar con libreria os de python

# %%
import os
path='/content/drive/My Drive/PDI/'
os.chdir(path)
# !pwd
from google.colab.patches import cv2_imshow
img = cv2.imread("tortuga.jpg", cv2.IMREAD_UNCHANGED)
#img = cv2.resize(img, (int(500),int(500)))
cv2_imshow(img)
print(img.shape)
# Out:
# /content/drive/My Drive/PDI
# <PIL.Image.Image image mode=RGB size=480x360 at 0x7F8F50ED6630>
# (360, 480, 3)

# %% [markdown]
# # mostrar imagen con matplot

# %%
#import matplotlib.pyplot as plt
img_BGR = cv2.imread("tortuga.jpg", cv2.IMREAD_COLOR)
plt.figure(figsize=(7,7))
plt.imshow(img_BGR)
plt.show()

# %% [markdown]
# # escalar imagen interpolacion cubica

# %%
print(img_BGR.shape)
res= cv2.resize(img_BGR, None , fx=10, fy=10, interpolation = cv2.INTER_CUBIC)
print(res.shape)
plt.imshow(res)
plt.show()
# Out:
# (360, 480, 3)
# (3600, 4800, 3)

# %% [markdown]
# # reducir una imagen interpolación cubica

# %%
print(img_BGR.shape)
res= cv2.resize(img_BGR, None , fx=.1, fy=.1, interpolation = cv2.INTER_CUBIC)
print(res.shape)
#remover numeracion de los ejes
plt.xticks([])
plt.yticks([])
plt.imshow(res)
plt.show()
# Out:
# (360, 480, 3)
# (36, 48, 3)

# %% [markdown]
# # de bgr a rgb

# %%
img_RGB=cv2.cvtColor(img_BGR, cv2.COLOR_BGR2RGB)

plt.imshow(img_RGB)
plt.xticks([])
plt.yticks([])
plt.show()
print(img_RGB.shape)
# Out:
# (360, 480, 3)

# %% [markdown]
# # convertir a escala de grises

# %%
img_GRAY=cv2.cvtColor(img_BGR, cv2.COLOR_BGR2GRAY)

plt.imshow(img_GRAY,cmap='gray')
plt.xticks([])
plt.yticks([])
plt.show()
print(img_GRAY.shape)
# Out:
# (360, 480)

# %% [markdown]
# # CREAR METODOS PARA MOSTRAR LAS IMAGENES

# %%
#Display 2 images
def mostrar2(im1, im2, title1="original", title2="editado"):
  plt.figure(figsize=(14,14))
  plt.subplot(121), plt.imshow(im1), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(122), plt.imshow(im2), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.show()

def mostrar(im1, title="original"):
  plt.imshow(im1), plt.title(title)
  plt.xticks([]), plt.yticks([])
  plt.show()
  
mostrar(img_RGB)
im2 = cv2.cvtColor(res, cv2.COLOR_BGR2RGB)

mostrar2(img_RGB,im2)

# %% [markdown]
# Estadisticas de la imagen

# %%
def estadisticas(img):
  img_size = img.shape
  
  if len(img_size)>2:
    print('image chanels',img_size[2])
  else:
    print("image chanels",1)
  
  print("image W",img_size[1])
  print("image H",img_size[0])
  print("min_value",img.min())
  print("max_value",img.max())
  print("prom_value",img.mean())
  print("type",img.dtype)
  
estadisticas(img_GRAY)
# Out:
# image chanels 1
# image W 480
# image H 360
# min_value 13
# max_value 255
# prom_value 103.92296296296297
# type uint8

# %%
images = []
IMAGE_DIRECTORY = '/content/drive/My Drive/PDI/'
def get_image(image_path):
  image = cv2.imread(image_path)
  image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
  return image

for file in os.listdir(IMAGE_DIRECTORY):
  if not file.startswith('.'):
    images.append(get_image(os.path.join(IMAGE_DIRECTORY,file)))

plt.figure(figsize=(20,10))
for i in range(len(images)):
  plt.subplot(1,len(images),i+1)
  plt.imshow(images[i])
