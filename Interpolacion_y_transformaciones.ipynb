# %% [markdown]
# <a href="https://colab.research.google.com/github/gabriel990420/PDI1/blob/master/Interpolacion_y_transformaciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

path = "/content/drive/My Drive/PDI/interpolaciones/"
os.chdir(path)
# !pwd
# graficar imagenes estaticas en el notebook
# %matplotlib inline
# Out:
# /content/drive/My Drive/PDI/interpolaciones

# %%
def mostrar3Grises(im1, im2, im3, title1="original", title2="Editado1", title3="Editado2"):
  plt.figure(figsize=(14,14))
  plt.subplot(131), plt.imshow(im1, cmap= 'gray'), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(132), plt.imshow(im2, cmap='gray'), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.subplot(133), plt.imshow(im3, cmap='gray'), plt.title(title3)
  plt.xticks([]), plt.yticks([])
  plt.show()
  
def mostrar2Grises(im1, im2, title1="original", title2="Editado2"):
  plt.figure(figsize=(14,14))
  plt.subplot(121), plt.imshow(im1, cmap= 'gray'), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(122), plt.imshow(im2, cmap='gray'), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.show()
  
def mostrar3Colores(im1, im2, im3, title1="original", title2="Editado1", title3="Editado2"):
  plt.figure(figsize=(14,14))
  plt.subplot(131), plt.imshow(im1), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(132), plt.imshow(im2), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.subplot(133), plt.imshow(im3), plt.title(title3)
  plt.xticks([]), plt.yticks([])
  plt.show()
  
def mostrar2Colores(im1, im2, title1="original", title2="Editado2"):
  plt.figure(figsize=(7,7))
  plt.subplot(121), plt.imshow(im1), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(122), plt.imshow(im2), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.show()

# %% [markdown]
# # **Interpolacion Vecino mas cercano**

# %%
file1 = path+"ico.jpg"
file2 = path+"apple20x22.jpg"
im = cv2.imread(file1)
im2 = cv2.imread(file2)
imRGB = cv2.cvtColor(im,cv2.COLOR_BGR2RGB)
imRGB2 = cv2.cvtColor(im2,cv2.COLOR_BGR2RGB)

near_imgA = cv2.resize(imRGB, None, fx = 1, fy = 1, interpolation = cv2.INTER_NEAREST)
near_imgB = cv2.resize(imRGB2, None, fx = 5, fy = 5, interpolation = cv2.INTER_NEAREST)

mostrar2Colores(near_imgA, near_imgB, "señora", "manzana")

# %% [markdown]
# #**Interpolacion Bilineal**

# %%
file1 = path+"ico.jpg"
file2 = path+"apple20x22.jpg"
im = cv2.imread(file1)
im2 = cv2.imread(file2)
imRGB = cv2.cvtColor(im,cv2.COLOR_BGR2RGB)
imRGB2 = cv2.cvtColor(im2,cv2.COLOR_BGR2RGB)

linear_imgA = cv2.resize(imRGB, None, fx = 5, fy = 5, interpolation = cv2.INTER_LINEAR)
linear_imgB = cv2.resize(imRGB2, None, fx = 5, fy = 5, interpolation = cv2.INTER_LINEAR)

mostrar2Colores(linear_imgA, linear_imgB, "señora", "manzana")

# %% [markdown]
# #**Interpolacion Bicubica**

# %%
file1 = path+"ico.jpg"
file2 = path+"apple20x22.jpg"
im = cv2.imread(file1)
im2 = cv2.imread(file2)
imRGB = cv2.cvtColor(im,cv2.COLOR_BGR2RGB)
imRGB2 = cv2.cvtColor(im2,cv2.COLOR_BGR2RGB)

cubic_imgA = cv2.resize(imRGB, None, fx = 5, fy = 5, interpolation = cv2.INTER_CUBIC)
cubic_imgB = cv2.resize(imRGB2, None, fx = 5, fy = 5, interpolation = cv2.INTER_CUBIC)

mostrar2Colores(cubic_imgA, cubic_imgB, "señora", "manzana")

# %%
methods = [None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos']

grid = imRGB2

fig, axes = plt.subplots(3, 6, figsize = (12,6), subplot_kw ={'xticks': [], 'yticks': []})
fig.subplots_adjust(hspace=0.3, wspace = 0.05)

for ax, interp_method in zip(axes.flat, methods):
  ax.imshow(grid, interpolation = interp_method)
  ax.set_title(interp_method)
  
plt.show()

# %%
methods = [None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos']

grid = np.random.rand(4,4)

fig, axes = plt.subplots(3, 6, figsize = (12,6), subplot_kw ={'xticks': [], 'yticks': []})
fig.subplots_adjust(hspace=0.3, wspace = 0.05)

for ax, interp_method in zip(axes.flat, methods):
  ax.imshow(grid, interpolation = interp_method)
  ax.set_title(interp_method)
  
plt.show()

# %%
from PIL import Image
foto = Image.open('/content/drive/My Drive/PDI/tortuga.jpg')
datos=list(foto.getdata())
datos_invertidos =[(255-datos[x][0],255-datos[x][1],255-datos[x][2]) for x in range(len(datos))]
imagen_invertida=Image.new('RGB',foto.size)
imagen_invertida.putdata(datos_invertidos)
plt.imshow(np.asarray(imagen_invertida))

# %%
foto = Image.open('ojo.jpg')
datos=list(foto.getdata())
datos_invertidos =[255-x for x in datos]
imagen_invertida=Image.new('L',foto.size)
imagen_invertida.putdata(datos_invertidos)
plt.imshow(np.asarray(imagen_invertida),cmap='gray')

# %%
def negative(L):
  #cargar imagen
  img = cv2.imread("ojo.jpg", cv2.IMREAD_GRAYSCALE)
  rows, columns = img.shape
  img2 = np.zeros((rows, columns), dtype= np.uint8)
  for x in range(rows):
    for y in range(columns):
      img2[x,y] = (L-1)-img[x,y]
  mostrar2Grises(img, img2, 'original', 'negativo')
  return 

negative(2**8)

# %%
img = cv2.imread('ojo.jpg')
img_log = (np.log(img+1)/(np.log(1+np.max(img))))*255
img_log = np.array(img_log, dtype = np.uint8)
mostrar2Grises(img, img_log)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
img = cv2.imread('tree.png')
gamma_two_point_two= np.array(255*(img/255)**2.2, dtype ='uint8')
gamma_point_four= np.array(255*(img/255)**0.4,dtype='uint8')
mostrar2Grises(gamma_two_point_two,gamma_point_four,'gamma 2.2','gamma 0.4')
